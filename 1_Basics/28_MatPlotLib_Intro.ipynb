# %% [markdown]
# # 28 MatPlotLib Intro

# %% [markdown]
# Go-to source to visualise data :)
#
# To access the complete documentation, go to the [matploblib website.](https://matplotlib.org/)
#
# The main useful areas on the website are on plot types area and also the cheatsheets.
#
# - Plot types: shows all the possible plot types and gives you code examples
# - Cheatsheets: overview on all the charts available and formatting

# %%
# check if we have matplotlib installed
# !pip list
# Out:
# Package            Version
# ------------------ -----------
# aiohappyeyeballs   2.4.3
# aiohttp            3.10.10
# aiosignal          1.3.1
# asttokens          2.4.1
# attrs              24.2.0
# certifi            2024.8.30
# charset-normalizer 3.4.0
# colorama           0.4.6
# comm               0.2.2
# datasets           3.0.1
# debugpy            1.8.7
# decorator          5.1.1
# dill               0.3.8
# executing          2.1.0
# filelock           3.16.1
# frozenlist         1.4.1
# fsspec             2024.6.1
# huggingface-hub    0.26.1
# idna               3.10
# ipykernel          6.29.5
# ipython            8.28.0
# jedi               0.19.1
# jupyter_client     8.6.3
# jupyter_core       5.7.2
# matplotlib-inline  0.1.7
# multidict          6.1.0
# multiprocess       0.70.16
# nest-asyncio       1.6.0
# numpy              2.1.2
# packaging          24.1
# pandas             2.2.3
# parso              0.8.4
# platformdirs       4.3.6
# prompt_toolkit     3.0.48
# propcache          0.2.0
# psutil             6.0.0
# pure_eval          0.2.3
# pyarrow            17.0.0
# Pygments           2.18.0
# pyjokes            0.8.3
# python-dateutil    2.9.0.post0
# pytz               2024.2
# pywin32            307
# PyYAML             6.0.2
# pyzmq              26.2.0
# requests           2.32.3
# six                1.16.0
# stack-data         0.6.3
# tornado            6.4.1
# tqdm               4.66.5
# traitlets          5.14.3
# typing_extensions  4.12.2
# tzdata             2024.2
# urllib3            2.2.3
# wcwidth            0.2.13
# xxhash             3.5.0
# yarl               1.16.0
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: C:\Users\erard\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
# install matplotlib

# !pip install matplotlib
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.9.2-cp311-cp311-win_amd64.whl.metadata (11 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.3.0-cp311-cp311-win_amd64.whl.metadata (5.4 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.54.1-cp311-cp311-win_amd64.whl.metadata (167 kB)
#      ---------------------------------------- 0.0/167.0 kB ? eta -:--:--
#      --------------------------- ---------- 122.9/167.0 kB 2.4 MB/s eta 0:00:01
#      -------------------------------------- 167.0/167.0 kB 3.4 MB/s eta 0:00:00
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.4.7-cp311-cp311-win_amd64.whl.metadata (6.4 kB)
# Requirement already satisfied: numpy>=1.23 in c:\users\erard\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (2.1.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\erard\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (24.1)
# Collecting pillow>=8 (from matplotlib)
#   Downloading pillow-11.0.0-cp311-cp311-win_amd64.whl.metadata (9.3 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib)
#   Downloading pyparsing-3.2.0-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\erard\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\erard\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Downloading matplotlib-3.9.2-cp311-cp311-win_amd64.whl (7.8 MB)
#    ---------------------------------------- 0.0/7.8 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/7.8 MB 9.4 MB/s eta 0:00:01
#    ---- ----------------------------------- 1.0/7.8 MB 10.1 MB/s eta 0:00:01
#    -------- ------------------------------- 1.6/7.8 MB 11.4 MB/s eta 0:00:01
#    ------------ --------------------------- 2.5/7.8 MB 13.1 MB/s eta 0:00:01
#    ------------------ --------------------- 3.6/7.8 MB 15.1 MB/s eta 0:00:01
#    ------------------------ --------------- 4.9/7.8 MB 17.3 MB/s eta 0:00:01
#    ------------------------------- -------- 6.1/7.8 MB 18.5 MB/s eta 0:00:01
#    ---------------------------------- ----- 6.7/7.8 MB 18.7 MB/s eta 0:00:01
#    ------------------------------------- -- 7.3/7.8 MB 18.0 MB/s eta 0:00:01
#    ---------------------------------------- 7.8/7.8 MB 17.3 MB/s eta 0:00:00
# Downloading contourpy-1.3.0-cp311-cp311-win_amd64.whl (217 kB)
#    ---------------------------------------- 0.0/217.2 kB ? eta -:--:--
#    ------------------------------ --------- 163.8/217.2 kB ? eta -:--:--
#    ------------------------------ --------- 163.8/217.2 kB ? eta -:--:--
#    ------------------------------ --------- 163.8/217.2 kB ? eta -:--:--
#    ----------------------------------- ---- 194.6/217.2 kB 1.1 MB/s eta 0:00:01
#    ---------------------------------------- 217.2/217.2 kB 1.1 MB/s eta 0:00:00
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.54.1-cp311-cp311-win_amd64.whl (2.2 MB)
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ------------------------- -------------- 1.4/2.2 MB 29.8 MB/s eta 0:00:01
#    ---------------------------------------  2.2/2.2 MB 23.4 MB/s eta 0:00:01
#    ---------------------------------------- 2.2/2.2 MB 23.4 MB/s eta 0:00:00
# Downloading kiwisolver-1.4.7-cp311-cp311-win_amd64.whl (56 kB)
#    ---------------------------------------- 0.0/56.0 kB ? eta -:--:--
#    ---------------------------------------- 56.0/56.0 kB ? eta 0:00:00
# Downloading pillow-11.0.0-cp311-cp311-win_amd64.whl (2.6 MB)
#    ---------------------------------------- 0.0/2.6 MB ? eta -:--:--
#    -------------------- ------------------- 1.3/2.6 MB 27.9 MB/s eta 0:00:01
#    -------------------------------- ------- 2.1/2.6 MB 22.0 MB/s eta 0:00:01
#    ---------------------------------------- 2.6/2.6 MB 20.5 MB/s eta 0:00:00
# Downloading pyparsing-3.2.0-py3-none-any.whl (106 kB)
#    ---------------------------------------- 0.0/106.9 kB ? eta -:--:--
#    ---------------------------------------- 106.9/106.9 kB 6.4 MB/s eta 0:00:00
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.3.0 cycler-0.12.1 fonttools-4.54.1 kiwisolver-1.4.7 matplotlib-3.9.2 pillow-11.0.0 pyparsing-3.2.0
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: C:\Users\erard\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
# let's import a specific module 

import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.arange(0, 5, 0.1)
y = np.sin(x)
plt.plot(x, y)

# %% [markdown]
# # 28 Problems

# %% [markdown]
# ## 1.28.1

# %% [markdown]
# Create a simple line plot with the pyplot module of matplotlib, using the number of job postings over the first 4 months of the year. Use the months as the x-axis and the number of postings as the y-axis. Below are the given variables.
#
# months = ['January', 'February', 'March', 'April']
#
# postings = [120, 150, 100, 130]

# %%
# defining variables

months = ['January', 'February', 'March', 'April']
postings = [120, 150, 100, 130]

# plotting
plt.plot(months, postings)
plt.show()

# %% [markdown]
# ## 1.28.2

# %% [markdown]
# Create a bar chart showing the number of job postings for different job titles. Below are the given variables for the job_titles and the associated number of job postings.
#
# job_titles = ['Data Analyst', 'Data Scientist', 'Data Engineer']
#
# postings = [50, 75, 60]

# %%
# variables
job_titles = ['Data Analyst', 'Data Scientist', 'Data Engineer']
postings = [50, 75, 60]

# plotting
plt.bar(job_titles, postings)
plt.show()
